# %%
filename = "test.jpg"
grid_rows = 8
grid_cols = 8

# %%
import cv2

img = cv2.imread(filename)
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/chris/Auto_OPDx (Flourescence)/.venv/lib/python3.14/site-packages/cv2/qt/plugins"
